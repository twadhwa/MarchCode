# %%
# day 7

count=0
n=int(input("enter a number: "))
while n!=0:
    r=n%10
    count=count+1
    n=n//10
    
print("no. of digits in entered number are:",count)
# Out:
# enter a number: 12345
# no. of digits in entered number are: 5
